# %%
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
sns.set(style='darkgrid')

# %%
pkm = pd.read_excel('Tabela Pokemon.xlsx')

# %%
pkm
# Out:
#             Nome  Numero    Tipo 1  Tipo 2  Altura m  Peso Kg  Catch Rate  \
# 0      Bulbasaur       1     Grass  Poison       0.7      6.9          45
# 1        Ivysaur       2     Grass  Poison       1.0     13.0          45
# 2       Venusaur       3     Grass  Poison       2.0    100.0          45
# 3     Charmander       4      Fire     NaN       0.6      8.5          45
# 4     Charmeleon       5      Fire     NaN       1.1     19.0          45
# ..           ...     ...       ...     ...       ...      ...         ...
# 804    Stakataka     805      Rock   Steel       5.5    820.0          30
# 805  Blacephalon     806      Fire   Ghost       1.8     13.0          30
# 806      Zeraora     807  Electric     NaN       1.5     44.5           3
# 807       Meltan     808     Steel     NaN       0.2      8.0           3
# 808     Melmetal     809     Steel     NaN       2.5    800.0           3
#
#      Male  Female   Hp  Atk  Def  SpA  SpD  Spe  Total  Media Lendario
# 0    87.5    12.5   45   49   49   65   65   45    318   53.0      Nao
# 1    87.5    12.5   60   62   63   80   80   60    405   67.5      Nao
# 2    87.5    12.5   80   82   83  100  100   80    525   87.5      Nao
# 3    87.5    12.5   39   52   43   60   50   65    309   51.5      Nao
# 4    87.5    12.5   58   64   58   80   65   80    405   67.5      Nao
# ..    ...     ...  ...  ...  ...  ...  ...  ...    ...    ...      ...
# 804   NaN     NaN   61  131  211   53  101   13    570   95.0      Nao
# 805   NaN     NaN   53  127   53  151   79  107    570   95.0      Nao
# 806   NaN     NaN   88  112   75  102   80  143    600  100.0      Nao
# 807   NaN     NaN   46   65   65   55   35   34    300   50.0      Nao
# 808   NaN     NaN  135  143  143   80   65   34    600  100.0      Nao
#
# [809 rows x 18 columns]

# %%
sns.jointplot(x='Lendario', y='Catch Rate', data=pkm)

# %%
pkm[pkm['Lendario'] == 'Sim']
# Out:
#            Nome  Numero    Tipo 1    Tipo 2  Altura m  Peso Kg  Catch Rate  \
# 143    Articuno     144       Ice    Flying       1.7     55.4           3
# 144      Zapdos     145  Electric    Flying       1.6     52.6           3
# 145     Moltres     146      Fire    Flying       2.0     60.0           3
# 149      Mewtwo     150   Psychic       NaN       2.0    122.0           3
# 242      Raikou     243  Electric       NaN       1.9    178.0           3
# 243       Entei     244      Fire       NaN       2.1    198.0           3
# 244     Suicune     245     Water       NaN       2.0    187.0           3
# 248       Lugia     249   Psychic    Flying       5.2    216.0           3
# 249       Ho-Oh     250      Fire    Flying       3.8    199.0           3
# 376    Regirock     377      Rock       NaN       1.7    230.0           3
# 377      Regice     378       Ice       NaN       1.8    175.0           3
# 378   Registeel     379     Steel       NaN       1.9    205.0           3
# 379      Latias     380    Dragon   Psychic       1.4     40.0           3
# 380      Latios     381    Dragon   Psychic       2.0     60.0           3
# 381      Kyogre     382     Water       NaN       4.5    352.0           3
# 382    Groundon     383    Ground       NaN       3.5    950.0           3
# 383    Rayquaza     384    Dragon    Flying       7.0    206.5          45
# 479        Uxie     480   Psychic       NaN       0.3      0.3           3
# 480     Mesprit     481   Psychic       NaN       0.3      0.3           3
# 481       Azelf     482   Psychic       NaN       0.3      0.3           3
# 482      Dialga     483     Steel    Dragon       5.4    683.0           3
# 483      Palkia     484     Water    Dragon       4.2    336.0           3
# 484     Heatran     485      Fire     Steel       1.7    430.0           3
# 485   Regigigas     486    Normal       NaN       3.7    420.0           3
# 486    Giratina     487     Ghost    Dragon       4.5    750.0           3
# 487   Cresselia     488   Psychic       NaN       1.5     85.6           3
# 637    Cobalion     638     Steel  Fighting       2.1    250.0           3
# 638   Terrakion     639      Rock  Fighting       1.9    260.0           3
# 639    Virizion     640     Grass  Fighting       2.0    200.0           3
# 640    Tornadus     641    Flying       NaN       1.5     63.0           3
# 641   Thundurus     642  Electric    Flying       1.5     61.0           3
# 642    Reshiram     643    Dragon      Fire       3.2    330.0           3
# 643      Zekrom     644    Dragon  Electric       2.9    345.0           3
# 644    Landorus     645    Ground    Flying       1.5     68.0           3
# 645      Kyurem     646    Dragon       Ice       3.0    325.0           3
# 715     Xerneas     716     Fairy       NaN       3.0    215.0          45
# 716     Yveltal     717      Dark    Flying       5.8    203.0          45
# 717     Zygarde     718    Dragon    Ground       5.0    305.0           3
# 771  Type: Null     772    Normal       NaN       1.9    120.5           3
# 772    Silvally     773    Normal       NaN       2.3    100.5           3
# 784   Tapu Koko     785  Electric     Fairy       1.8     20.5           3
# 785   Tapu Lele     786   Psychic     Fairy       1.2     18.6           3
# 786   Tapu Bulu     787     Grass     Fairy       1.9     45.5           3
# 787   Tapu Fini     788     Water     Fairy       1.3     21.2           3
# 788      Cosmog     789   Psychic       NaN       0.2      0.1          45
# 789     Cosmoem     790   Psychic       NaN       0.1    999.9          45
# 790    Solgaleo     791   Psychic     Steel       3.4    230.0          45
# 791      Lunala     792   Psychic     Ghost       4.0    120.0          45
# 799    Necrozma     800   Psychic       NaN       2.4    230.0         255
#
#       Male  Female   Hp  Atk  Def  SpA  SpD  Spe  Total       Media Lendario
# 143    NaN     NaN   90   85  100   95  125   85    580   96.666667      Sim
# 144    NaN     NaN   90   90   85  125   90  100    580   96.666667      Sim
# 145    NaN     NaN   90  100   90  125   85   90    580   96.666667      Sim
# 149    NaN     NaN  106  110   90  154   90  130    680  113.333333      Sim
# 242    NaN     NaN   90   85   75  115  100  115    580   96.666667      Sim
# 243    NaN     NaN  115  115   85   90   75  100    580   96.666667      Sim
# 244    NaN     NaN  100   75  115   90  115   85    580   96.666667      Sim
# 248    NaN     NaN  106   90  130   90  154  110    680  113.333333      Sim
# 249    NaN     NaN  106  130   90  110  154   90    680  113.333333      Sim
# 376    NaN     NaN   80  100  200   50  100   50    580   96.666667      Sim
# 377    NaN     NaN   80   50  100  100  200   50    580   96.666667      Sim
# 378    NaN     NaN   80   75  150   75  150   50    580   96.666667      Sim
# 379    0.0   100.0   80   80   90  110  130  110    600  100.000000      Sim
# 380  100.0     0.0   80   90   80  130  110  110    600  100.000000      Sim
# 381    NaN     NaN  100  100   90  150  140   90    670  111.666667      Sim
# 382    NaN     NaN  100  150  140  100   90   90    670  111.666667      Sim
# 383    NaN     NaN  105  150   90  150   90   95    680  113.333333      Sim
# 479    NaN     NaN   75   75  130   75  130   95    580   96.666667      Sim
# 480    NaN     NaN   80  105  105  105  105   80    580   96.666667      Sim
# 481    NaN     NaN   75  125   70  125   70  115    580   96.666667      Sim
# 482    NaN     NaN  100  120  120  150  100   90    680  113.333333      Sim
# 483    NaN     NaN   90  120  100  150  120  100    680  113.333333      Sim
# 484   50.0    50.0   91   90  106  130  106   77    600  100.000000      Sim
# 485    NaN     NaN  110  160  110   80  110  100    670  111.666667      Sim
# 486    NaN     NaN  150  100  120  100  120   90    680  113.333333      Sim
# 487    0.0   100.0  120   70  120   75  130   85    600  100.000000      Sim
# 637    NaN     NaN   91   90  129   90   72  108    580   96.666667      Sim
# 638    NaN     NaN   91  129   90   72   90  108    580   96.666667      Sim
# 639    NaN     NaN   91   90   72   90  129  108    580   96.666667      Sim
# 640  100.0     0.0   79  115   70  125   80  111    580   96.666667      Sim
# 641  100.0     0.0   79  115   70  125   80  111    580   96.666667      Sim
# 642    NaN     NaN  100  120  100  150  120   90    680  113.333333      Sim
# 643    NaN     NaN  100  150  120  120  100   90    680  113.333333      Sim
# 644  100.0     0.0   89  125   90  115   80  101    600  100.000000      Sim
# 645    NaN     NaN  125  130   90  130   90   95    660  110.000000      Sim
# 715    NaN     NaN  126  131   95  131   98   99    680  113.333333      Sim
# 716    NaN     NaN  126  131   95  131   98   99    680  113.333333      Sim
# 717    NaN     NaN  108  100  121   81   95   95    600  100.000000      Sim
# 771    NaN     NaN   95   95   95   95   95   59    534   89.000000      Sim
# 772    NaN     NaN   95   95   95   95   95   95    570   95.000000      Sim
# 784    NaN     NaN   70  115   85   95   75  130    570   95.000000      Sim
# 785    NaN     NaN   70   85   75  130  115   95    570   95.000000      Sim
# 786    NaN     NaN   70  130  115   85   95   75    570   95.000000      Sim
# 787    NaN     NaN   70   75  115   95  130   85    570   95.000000      Sim
# 788    NaN     NaN   43   29   31   29   31   37    200   33.333333      Sim
# 789    NaN     NaN   43   29  131   29  131   37    400   66.666667      Sim
# 790    NaN     NaN  137  137  107  113   89   97    680  113.333333      Sim
# 791    NaN     NaN  137  113   89  137  107   97    680  113.333333      Sim
# 799    NaN     NaN   97  107  101  127   89   79    600  100.000000      Sim

# %%
crr = pkm.corr()

# %%
sns.heatmap(crr)
# Out:
# <AxesSubplot:>

# %%
pkm[(100 - pkm['Male'] == pkm['Female']) | (100 - pkm['Female'] == pkm['Male'])]
# Out:
#            Nome  Numero  Tipo 1    Tipo 2  Altura m  Peso Kg  Catch Rate  \
# 0     Bulbasaur       1   Grass    Poison       0.7      6.9          45
# 1       Ivysaur       2   Grass    Poison       1.0     13.0          45
# 2      Venusaur       3   Grass    Poison       2.0    100.0          45
# 3    Charmander       4    Fire       NaN       0.6      8.5          45
# 4    Charmeleon       5    Fire       NaN       1.1     19.0          45
# ..          ...     ...     ...       ...       ...      ...         ...
# 778     Bruxish     779   Water   Psychic       0.9     19.0          80
# 779      Drampa     780  Normal    Dragon       3.0    185.0          70
# 781    Jangmo-o     782  Dragon       NaN       0.6     29.7          45
# 782    Hakamo-o     783  Dragon  Fighting       1.2     47.0          45
# 783     Kommo-o     784  Dragon  Fighting       1.6     78.2          45
#
#      Male  Female  Hp  Atk  Def  SpA  SpD  Spe  Total       Media Lendario
# 0    87.5    12.5  45   49   49   65   65   45    318   53.000000      Nao
# 1    87.5    12.5  60   62   63   80   80   60    405   67.500000      Nao
# 2    87.5    12.5  80   82   83  100  100   80    525   87.500000      Nao
# 3    87.5    12.5  39   52   43   60   50   65    309   51.500000      Nao
# 4    87.5    12.5  58   64   58   80   65   80    405   67.500000      Nao
# ..    ...     ...  ..  ...  ...  ...  ...  ...    ...         ...      ...
# 778  50.0    50.0  68  105   70   70   70   92    475   79.166667      Nao
# 779  50.0    50.0  78   60   85  135   91   36    485   80.833333      Nao
# 781  50.0    50.0  45   55   65   45   45   45    300   50.000000      Nao
# 782  50.0    50.0  55   75   90   65   70   65    420   70.000000      Nao
# 783  50.0    50.0  75  110  125  100  105   85    600  100.000000      Nao
#
# [702 rows x 18 columns]

# %%
pkm[pkm['Numero'] == 781]
# Out:
#          Nome  Numero Tipo 1 Tipo 2  Altura m  Peso Kg  Catch Rate  Male  \
# 780  Dhelmise     781  Ghost  Grass       3.9    210.0          25   NaN
#
#      Female  Hp  Atk  Def  SpA  SpD  Spe  Total      Media Lendario
# 780     NaN  70  131  100   86   90   40    517  86.166667      Nao

# %%
sns.clustermap(crr, standard_scale=1)
