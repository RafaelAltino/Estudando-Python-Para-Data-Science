# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pkm = pd.read_excel('Tabela Pokemon.xlsx')

# %%
pkm
# Out:
#             Nome  Numero    Tipo 1  Tipo 2  Altura m  Peso Kg  Catch Rate  \
# 0      Bulbasaur       1     Grass  Poison       0.7      6.9          45
# 1        Ivysaur       2     Grass  Poison       1.0     13.0          45
# 2       Venusaur       3     Grass  Poison       2.0    100.0          45
# 3     Charmander       4      Fire     NaN       0.6      8.5          45
# 4     Charmeleon       5      Fire     NaN       1.1     19.0          45
# ..           ...     ...       ...     ...       ...      ...         ...
# 804    Stakataka     805      Rock   Steel       5.5    820.0          30
# 805  Blacephalon     806      Fire   Ghost       1.8     13.0          30
# 806      Zeraora     807  Electric     NaN       1.5     44.5           3
# 807       Meltan     808     Steel     NaN       0.2      8.0           3
# 808     Melmetal     809     Steel     NaN       2.5    800.0           3
#
#      Male  Female   Hp  Atk  Def  SpA  SpD  Spe  Total  Media Lendario
# ...

# %%
qnt = ((pkm['Tipo 1'].value_counts()) + (pkm['Tipo 2'].value_counts()))
qnt.sort_index(inplace = True)

tipos = np.sort(pkm['Tipo 1'].unique())

# %%
fig = plt.figure(figsize=(12,4))
ax = fig.add_axes([0,0,1,1])
ax.plot(tipos, qnt)

# %%
tipos = np.sort(pkm['Tipo 1'].unique())
tipos
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(15,4))
ax.bar(tipos, qnt)
ax.set_xlabel('Tipo')
ax.set_ylabel('Quantidade')
ax.set_title('Quantidade de Pokemons por tipo')
# Out:
# Text(0.5, 1.0, 'Quantidade de Pokemons por tipo')

# %%
unicos = pkm[pd.isna(pkm['Tipo 2'])]['Tipo 1'].value_counts()
unicos.sort_index(inplace = True)
unicos
# Out:
# Bug         18
# Dark         9
# Dragon      13
# Electric    28
# Fairy       16
# Fighting    22
# Fire        30
# Flying       1
# Ghost       10
# Grass       38
# Ground      15
# Ice         12
# Normal      65
# Poison      16
# Psychic     35
# Rock        11
# Steel        6
# Water       61
# Name: Tipo 1, dtype: int64

# %%
fig, ax2 = plt.subplots(figsize=(15,4))
ax2.bar(tipos, unicos)
ax2.set_xlabel('Tipo')
ax2.set_ylabel('Quantidade')
ax2.set_title('Quantidade de Pokemons de tipo único')
# Out:
# Text(0.5, 1.0, 'Quantidade de Pokemons de tipo único')

# %%
#Todos os pokemons exclusivamente do tipo metal
pkm[(pkm['Tipo 1'] == 'Steel') & (pd.isna(pkm['Tipo 2']))]
# Out:
#           Nome  Numero Tipo 1 Tipo 2  Altura m  Peso Kg  Catch Rate  Male  \
# 378  Registeel     379  Steel    NaN       1.9    205.0           3   NaN
# 598      Klink     599  Steel    NaN       0.3     21.0         130   NaN
# 599      Klang     600  Steel    NaN       0.6     51.0          60   NaN
# 600  Klinklang     601  Steel    NaN       0.6     81.0          30   NaN
# 807     Meltan     808  Steel    NaN       0.2      8.0           3   NaN
# 808   Melmetal     809  Steel    NaN       2.5    800.0           3   NaN
#
#      Female   Hp  Atk  Def  SpA  SpD  Spe  Total       Media Lendario
# 378     NaN   80   75  150   75  150   50    580   96.666667      Sim
# 598     NaN   40   55   70   45   60   30    300   50.000000      Nao
# 599     NaN   60   80   95   70   85   50    440   73.333333      Nao
# 600     NaN   60  100  115   70   85   90    520   86.666667      Nao
# 807     NaN   46   65   65   55   35   34    300   50.000000      Nao
# ...
